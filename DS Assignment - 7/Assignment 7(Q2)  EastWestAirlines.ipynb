# %%
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pylab as plt
import scipy.cluster.hierarchy as sch
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
from scipy.spatial.distance import cdist
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import AgglomerativeClustering
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load dataset

# %%
air=pd.read_excel('D://DATA SCIENCE ASSIGNMENTS//Clustering//EastWestAirlines.xlsx',sheet_name='data')

# %%
air
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 0               1                  0                0               7000
# 1               2                  0                0               6968
# 2               4                  0                0               7034
# 3               1                  0                0               6952
# 4              26               2077                4               6935
# ...           ...                ...              ...                ...
# 3994            4                200                1               1403
# 3995            5                  0                0               1395
# 3996            8                  0                0               1402
# 3997            1                500                1               1401
# 3998            0                  0                0               1398
#
#       Award?
# 0          0
# 1          0
# 2          0
# 3          0
# 4          1
# ...      ...
# 3994       1
# 3995       1
# 3996       1
# 3997       0
# 3998       0
#
# [3999 rows x 12 columns]

# %%
air.rename(columns={'ID#':'id'}, inplace=True)
air.columns[0]
# Out:
# 'id'

# %%
df1 = air.copy()

# %%
# Checking for duplicates
air['id'].duplicated().sum()
# Out:
# 0

# %%
# Dropping the id column
air2=air.drop(['id'],axis=1)
air2.head()
# Out:
#    Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    28143           0          1          1          1          174
# 1    19244           0          1          1          1          215
# 2    41354           0          1          1          1         4123
# 3    14776           0          1          1          1          500
# 4    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
df1.head()
# Out:
#    id  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0   1    28143           0          1          1          1          174
# 1   2    19244           0          1          1          1          215
# 2   3    41354           0          1          1          1         4123
# 3   4    14776           0          1          1          1          500
# 4   5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing

# %%
df1_norm = preprocessing.scale(df1)

# %%
df1_norm = pd.DataFrame(df1_norm) #standardize the data to normal distribution

# %%
df1_norm.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -1.735125 -0.451141 -0.186299 -0.769578 -0.098242 -0.062767 -0.702786
# 1 -1.734263 -0.539457 -0.186299 -0.769578 -0.098242 -0.062767 -0.701088
# 2 -1.733402 -0.320031 -0.186299 -0.769578 -0.098242 -0.062767 -0.539253
# 3 -1.732540 -0.583799 -0.186299 -0.769578 -0.098242 -0.062767 -0.689286
# 4 -1.731679  0.239678 -0.186299  1.409471 -0.098242 -0.062767  1.083121
#
#          7         8         9         10        11
# 0 -1.104065 -0.328603 -0.362168  1.395454 -0.766919
# 1 -0.999926 -0.328603 -0.362168  1.379957 -0.766919
# 2 -0.791649 -0.328603 -0.362168  1.411920 -0.766919
# 3 -1.104065 -0.328603 -0.362168  1.372208 -0.766919
# 4  1.499394  1.154932  0.692490  1.363975  1.303918

# %% [markdown]
# ### Finding out the optimal number of clusters

# %%
plt.figure(figsize=(10, 8))
wcss = []
for i in range(1, 15):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(df1_norm)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 15), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
df1.shape
# Out:
# (3999, 12)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
air.describe()
# Out:
#                ID#       Balance    Qual_miles    cc1_miles    cc2_miles  \
# count  3999.000000  3.999000e+03   3999.000000  3999.000000  3999.000000
# mean   2014.819455  7.360133e+04    144.114529     2.059515     1.014504
# std    1160.764358  1.007757e+05    773.663804     1.376919     0.147650
# min       1.000000  0.000000e+00      0.000000     1.000000     1.000000
# 25%    1010.500000  1.852750e+04      0.000000     1.000000     1.000000
# 50%    2016.000000  4.309700e+04      0.000000     1.000000     1.000000
# 75%    3020.500000  9.240400e+04      0.000000     3.000000     1.000000
# max    4021.000000  1.704838e+06  11148.000000     5.000000     3.000000
#
#          cc3_miles    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# count  3999.000000    3999.000000   3999.00000        3999.000000
# mean      1.012253   17144.846212     11.60190         460.055764
# std       0.195241   24150.967826      9.60381        1400.209171
# min       1.000000       0.000000      0.00000           0.000000
# 25%       1.000000    1250.000000      3.00000           0.000000
# 50%       1.000000    7171.000000     12.00000           0.000000
# 75%       1.000000   23800.500000     17.00000         311.000000
# max       5.000000  263685.000000     86.00000       30817.000000
#
#        Flight_trans_12  Days_since_enroll       Award?
# count      3999.000000         3999.00000  3999.000000
# mean          1.373593         4118.55939     0.370343
# std           3.793172         2065.13454     0.482957
# min           0.000000            2.00000     0.000000
# 25%           0.000000         2330.00000     0.000000
# 50%           0.000000         4096.00000     0.000000
# 75%           1.000000         5790.50000     1.000000
# max          53.000000         8296.00000     1.000000

# %%
# Count of duplicates rows
air[air.duplicated()].shape
# Out:
# (0, 12)

# %%
df1['Balance'].plot(figsize=(12, 5))
plt.show()

# %% [markdown]
# # HIERARCHICAL

# %%
# Normalization function 
def norm_func(i):
    x = (i-i.min())/(i.max()-i.min())
    return (x)

# %%
air1=(air.iloc[:,1:])
air1
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 0               1                  0                0               7000
# 1               2                  0                0               6968
# 2               4                  0                0               7034
# 3               1                  0                0               6952
# 4              26               2077                4               6935
# ...           ...                ...              ...                ...
# 3994            4                200                1               1403
# 3995            5                  0                0               1395
# 3996            8                  0                0               1402
# 3997            1                500                1               1401
# 3998            0                  0                0               1398
#
#       Award?
# 0          0
# 1          0
# 2          0
# 3          0
# 4          1
# ...      ...
# 3994       1
# 3995       1
# 3996       1
# 3997       0
# 3998       0
#
# [3999 rows x 11 columns]

# %%
# Normalized data frame (considering the numerical part of data)
air1_norm = norm_func(air1.iloc[:,1:])

# %%
air1_norm
# Out:
#       Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  Bonus_trans  \
# 0            0.0       0.00        0.0        0.0     0.000660     0.011628
# 1            0.0       0.00        0.0        0.0     0.000815     0.023256
# 2            0.0       0.00        0.0        0.0     0.015636     0.046512
# 3            0.0       0.00        0.0        0.0     0.001896     0.011628
# 4            0.0       0.75        0.0        0.0     0.164211     0.302326
# ...          ...        ...        ...        ...          ...          ...
# 3994         0.0       0.00        0.0        0.0     0.032330     0.046512
# 3995         0.0       0.00        0.0        0.0     0.003720     0.058140
# 3996         0.0       0.50        0.0        0.0     0.096505     0.093023
# 3997         0.0       0.00        0.0        0.0     0.001896     0.011628
# 3998         0.0       0.00        0.0        0.0     0.000000     0.000000
#
#       Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0              0.000000         0.000000           0.843742     0.0
# 1              0.000000         0.000000           0.839884     0.0
# 2              0.000000         0.000000           0.847842     0.0
# 3              0.000000         0.000000           0.837955     0.0
# 4              0.067398         0.075472           0.835905     1.0
# ...                 ...              ...                ...     ...
# 3994           0.006490         0.018868           0.168917     1.0
# 3995           0.000000         0.000000           0.167953     1.0
# 3996           0.000000         0.000000           0.168797     1.0
# 3997           0.016225         0.018868           0.168676     0.0
# 3998           0.000000         0.000000           0.168314     0.0
#
# [3999 rows x 10 columns]

# %%
plt.figure(figsize=(15,12));plt.title('HIERARCHY DENDROGRAM');plt.xlabel('Index');plt.ylabel('Distance')
dendograms=sch.dendrogram(sch.linkage(air1_norm,"complete"))
plt.show()

# %%
# create clusters
hc = AgglomerativeClustering(n_clusters=3, affinity = 'euclidean', linkage = 'single')

# %%
hc
# Out:
# AgglomerativeClustering(affinity='euclidean', linkage='single', n_clusters=3)

# %%
# save clusters for chart
y_hc = hc.fit_predict(air1_norm)
Clusters=pd.DataFrame(y_hc,columns=['Clusters'])

# %%
Clusters
# Out:
#       Clusters
# 0            1
# 1            1
# 2            1
# 3            1
# 4            0
# ...        ...
# 3994         0
# 3995         0
# 3996         0
# 3997         1
# 3998         1
#
# [3999 rows x 1 columns]

# %% [markdown]
# ## H Clustering

# %%
import scipy.cluster.hierarchy as sch
dendrogram = sch.dendrogram(sch.linkage(df1_norm, method='ward'))

# %%
X = df1_norm.values

# %%
model = AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='ward')

# %%
h_cluster = model.fit(X)

# %%
labels = model.labels_

# %%
labels = model.labels_

# %%
plt.scatter(X[labels==0, 0], X[labels==0, 1], s=50, marker='o', color='red')
plt.scatter(X[labels==1, 0], X[labels==1, 1], s=50, marker='o', color='blue')
plt.scatter(X[labels==2, 0], X[labels==2, 1], s=50, marker='o', color='green')

# %% [markdown]
# # K-MEANS

# %%
X = np.random.uniform(0,1,1000)
Y = np.random.uniform(0,1,1000)
df_xy =pd.DataFrame(columns=["X","Y"])
df_xy.X = X
df_xy.Y = Y
df_xy.plot(x="X",y = "Y",kind="scatter")
# Out:
# <Axes: xlabel='X', ylabel='Y'>

# %%
X = np.random.uniform(0,1,1000)
X
# Out:
# array([0.30447746, 0.49360035, 0.96460555, 0.21385358, 0.12300337,
#        0.3493537 , 0.94076844, 0.93839241, 0.17095591, 0.03136257,
#        0.85406302, 0.39357016, 0.5720451 , 0.70619747, 0.79508188,
#        0.88404618, 0.16125345, 0.05696547, 0.32065709, 0.7784876 ,
#        0.73197109, 0.21531182, 0.65803649, 0.63177795, 0.01363957,
#        0.31102766, 0.33832156, 0.12012662, 0.73492224, 0.46036143,
#        0.52474234, 0.50938962, 0.53651612, 0.58492493, 0.85205383,
#        0.71619657, 0.04135497, 0.03157672, 0.29197754, 0.81715049,
#        0.62627311, 0.95208629, 0.93627201, 0.48099528, 0.37117432,
#        0.8115115 , 0.99099204, 0.03780594, 0.08565504, 0.25408328,
#        0.11346391, 0.48463963, 0.14318852, 0.28167388, 0.50840276,
#        0.58007896, 0.85521897, 0.53121641, 0.0210962 , 0.37739114,
#        0.90071035, 0.89899855, 0.9480272 , 0.81327204, 0.34662855,
#        0.5701213 , 0.04891153, 0.56116818, 0.13173473, 0.72741857,
#        0.9670113 , 0.27966391, 0.65740809, 0.58644795, 0.66779576,
#        0.64079561, 0.45726354, 0.57036254, 0.6407606 , 0.67800367,
#        0.34687838, 0.59121343, 0.57089456, 0.78552825, 0.33046157,
#        0.18823071, 0.65526078, 0.52221424, 0.87065146, 0.27603704,
#        0.93085953, 0.66755476, 0.82964031, 0.70416608, 0.66283193,
#        0.83701106, 0.93400248, 0.52346121, 0.94555225, 0.7926056 ,
#        0.41545699, 0.25912809, 0.50481369, 0.97394515, 0.56519986,
#        0.30590899, 0.82863128, 0.20166241, 0.95523291, 0.96401399,
#        0.8171951 , 0.0028238 , 0.90531886, 0.16056576, 0.53842018,
#        0.82177828, 0.03032355, 0.38789191, 0.28781964, 0.00931753,
#        0.62990207, 0.30888891, 0.94073026, 0.88691466, 0.46881289,
#        0.17010917, 0.33450483, 0.44455707, 0.87836427, 0.54884607,
#        0.19038212, 0.61494985, 0.96137377, 0.47387743, 0.42430978,
#        0.20102369, 0.38397761, 0.8312318 , 0.73495477, 0.77866148,
#        0.52486251, 0.5170804 , 0.73737984, 0.08232233, 0.1164571 ,
#        0.88538529, 0.75888131, 0.55218866, 0.16726931, 0.07507718,
#        0.09529052, 0.77981951, 0.45993453, 0.93670953, 0.46727793,
#        0.78121821, 0.1110032 , 0.89913727, 0.38396674, 0.36401207,
#        0.12827648, 0.56116624, 0.228349  , 0.11400421, 0.66757274,
#        0.08755764, 0.31270272, 0.33832545, 0.19131646, 0.49870847,
#        0.15631959, 0.32417982, 0.62032816, 0.37498821, 0.07625456])

# %%
model1 = KMeans(n_clusters=5).fit(df_xy)

df_xy.plot(x="X",y = "Y",c=model1.labels_,kind="scatter",s=10,cmap=plt.cm.coolwarm)
# Out:
# <Axes: xlabel='X', ylabel='Y'>

# %%
air=pd.read_excel('D://DATA SCIENCE ASSIGNMENTS//Clustering//EastWestAirlines.xlsx',sheet_name='data')

# %%
# Normalization function 
def norm_func(i):
    x = (i-i.min())/(i.max()-i.min())
    return (x)

# Normalized data frame (considering the numerical part of data)
df_norm = norm_func(air.iloc[:,1:])


df_norm.head(10)  # Top 10 rows
# Out:
#     Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0  0.016508         0.0       0.00        0.0        0.0     0.000660
# 1  0.011288         0.0       0.00        0.0        0.0     0.000815
# 2  0.024257         0.0       0.00        0.0        0.0     0.015636
# 3  0.008667         0.0       0.00        0.0        0.0     0.001896
# 4  0.057338         0.0       0.75        0.0        0.0     0.164211
# 5  0.009631         0.0       0.00        0.0        0.0     0.000000
# 6  0.049808         0.0       0.50        0.0        0.0     0.104223
# 7  0.012233         0.0       0.00        0.0        0.0     0.019910
# 8  0.259850         0.0       0.50        0.5        0.0     0.006648
# 9  0.061507         0.0       0.50        0.0        0.0     0.107803
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0     0.011628           0.000000         0.000000           0.843742     0.0
# 1     0.023256           0.000000         0.000000           0.839884     0.0
# 2     0.046512           0.000000         0.000000           0.847842     0.0
# 3     0.011628           0.000000         0.000000           0.837955     0.0
# 4     0.302326           0.067398         0.075472           0.835905     1.0
# 5     0.000000           0.000000         0.000000           0.836749     0.0
# 6     0.290698           0.000000         0.000000           0.843019     0.0
# 7     0.046512           0.008112         0.018868           0.836267     1.0
# 8     0.500000           0.124931         0.226415           0.837473     1.0
# 9     0.325581           0.037317         0.056604           0.835423     1.0

# %%
# Selecting 5 clusters from the above scree plot which is the optimum number of clusters 
model=KMeans(n_clusters=5) 
model.fit(df_norm)

model.labels_ # getting the labels of clusters assigned to each row
# Out:
# array([4, 4, 4, ..., 2, 1, 1])

# %%
md=pd.Series(model.labels_)  # converting numpy array into pandas series object 
air['clust']=md # creating a  new column and assigning it to new column 
df_norm.head()
# Out:
#     Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0  0.016508         0.0       0.00        0.0        0.0     0.000660
# 1  0.011288         0.0       0.00        0.0        0.0     0.000815
# 2  0.024257         0.0       0.00        0.0        0.0     0.015636
# 3  0.008667         0.0       0.00        0.0        0.0     0.001896
# 4  0.057338         0.0       0.75        0.0        0.0     0.164211
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0     0.011628           0.000000         0.000000           0.843742     0.0
# 1     0.023256           0.000000         0.000000           0.839884     0.0
# 2     0.046512           0.000000         0.000000           0.847842     0.0
# 3     0.011628           0.000000         0.000000           0.837955     0.0
# 4     0.302326           0.067398         0.075472           0.835905     1.0

# %%
air.iloc[:,1:7].groupby(air.clust).mean()
# Out:
#              Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# clust
# 0      118297.325243   73.467638   3.584142   1.001618   1.022654
# 1       33097.301357   94.131783   1.070736   1.016473   1.006783
# 2      108317.387376  198.336634   3.915842   1.001238   1.025990
# 3       83529.153046  290.453195   1.156018   1.032689   1.008915
# 4       49921.633641   89.903226   1.122120   1.019585   1.001152
#
#         Bonus_miles
# clust
# 0      31384.393204
# 1       3244.520349
# 2      45609.657178
# 3       8850.395245
# 4       3467.074885

# %%
air.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?  \
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1
#
#    clust
# 0      4
# 1      4
# 2      4
# 3      4
# 4      2

# %%
Wcss=[]
for i in range(1,11):
    kmeans=KMeans(n_clusters=i,random_state=2)
    kmeans.fit(df_norm)
    Wcss.append(kmeans.inertia_)

# %%
plt.plot(range(1,11),Wcss)
plt.title('Elbow Graph')
plt.xlabel('Number of clusters')
plt.ylabel('Wcss')
plt.show()

# %%
kmeans = KMeans(n_clusters = 3, init = 'k-means++', random_state = 42)
k_means = kmeans.fit_predict(df1_norm)

# %%
kmeans.labels_
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
k_means1=k_means+1
k_cluster = list(k_means1)

# %%
df1['k_cluster'] = k_cluster

# %%
pd.DataFrame(round(df1.groupby('k_cluster').count(),1))
# Out:
#              id  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# k_cluster
# 1           164      164         164        164        164        164
# 2          2530     2530        2530       2530       2530       2530
# 3          1305     1305        1305       1305       1305       1305
#
#            Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# k_cluster
# 1                  164          164                164              164
# 2                 2530         2530               2530             2530
# 3                 1305         1305               1305             1305
#
#            Days_since_enroll  Award?
# k_cluster
# 1                        164     164
# 2                       2530    2530
# 3                       1305    1305

# %%
# Assign clusters to the data set
air4=air2.copy()
air4['k_cluster']=kmeans.labels_
air4
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 0               1                  0                0               7000
# 1               2                  0                0               6968
# 2               4                  0                0               7034
# 3               1                  0                0               6952
# 4              26               2077                4               6935
# ...           ...                ...              ...                ...
# 3994            4                200                1               1403
# 3995            5                  0                0               1395
# 3996            8                  0                0               1402
# 3997            1                500                1               1401
# 3998            0                  0                0               1398
#
#       Award?  k_cluster
# 0          0          1
# 1          0          1
# 2          0          1
# 3          0          1
# 4          1          2
# ...      ...        ...
# 3994       1          1
# 3995       1          1
# 3996       1          1
# 3997       0          1
# 3998       0          1
#
# [3999 rows x 12 columns]

# %%
# Group data by Clusters (K=4)
air4.groupby('clusters4_id').agg(['mean']).reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[91], line 2
#       1 # Group data by Clusters (K=4)
# ----> 2 air4.groupby('clusters4_id').agg(['mean']).reset_index()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:8252, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8249     raise TypeError("You have to supply one of 'by' and 'level'")
#    8250 axis = self._get_axis_number(axis)
# -> 8252 return DataFrameGroupBy(
#    8253     obj=self,
#    8254     keys=by,
#    8255     axis=axis,
#    8256     level=level,
#    8257     as_index=as_index,
#    8258     sort=sort,
#    8259     group_keys=group_keys,
#    8260     observed=observed,
#    8261     dropna=dropna,
#    8262 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:931, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#     928 self.dropna = dropna
#     930 if grouper is None:
# --> 931     grouper, exclusions, obj = get_grouper(
#     932         obj,
#     933         keys,
#     934         axis=axis,
#     935         level=level,
#     936         sort=sort,
#     937         observed=observed,
#     938         dropna=self.dropna,
#     939     )
#     941 self.obj = obj
#     942 self.axis = obj._get_axis_number(axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\grouper.py:985, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#     983         in_axis, level, gpr = False, gpr, None
#     984     else:
# --> 985         raise KeyError(gpr)
#     986 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     987     # Add key to exclusions
#     988     exclusions.add(gpr.key)
#
# KeyError: 'clusters4_id'

# %%
# Plot Clusters
plt.figure(figsize=(10, 7))  
plt.scatter(air4['k_cluster'],air4['Balance'], c=kmeans.labels_)

# %% [markdown]
# # DBSCAN

# %%
# Import .csv file and convert it to a DataFrame object
air=pd.read_excel('D://DATA SCIENCE ASSIGNMENTS//Clustering//EastWestAirlines.xlsx',sheet_name='data')

print(air.head())
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
print(air.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB
# None

# %%
air.drop(['ID#','Award?'],axis=1,inplace=True)

# %%
air
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll
# 0               1                  0                0               7000
# 1               2                  0                0               6968
# 2               4                  0                0               7034
# 3               1                  0                0               6952
# 4              26               2077                4               6935
# ...           ...                ...              ...                ...
# 3994            4                200                1               1403
# 3995            5                  0                0               1395
# 3996            8                  0                0               1402
# 3997            1                500                1               1401
# 3998            0                  0                0               1398
#
# [3999 rows x 10 columns]

# %%
array=air.values

# %%
array
# Out:
# array([[28143,     0,     1, ...,     0,     0,  7000],
#        [19244,     0,     1, ...,     0,     0,  6968],
#        [41354,     0,     1, ...,     0,     0,  7034],
#        ...,
#        [73597,     0,     3, ...,     0,     0,  1402],
#        [54899,     0,     1, ...,   500,     1,  1401],
#        [ 3016,     0,     1, ...,     0,     0,  1398]], dtype=int64)

# %%
stscaler = StandardScaler().fit(array)
X = stscaler.transform(array)

# %%
X
# Out:
# array([[-4.51140783e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.28603258e-01, -3.62167870e-01,  1.39545434e+00],
#        [-5.39456874e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.28603258e-01, -3.62167870e-01,  1.37995704e+00],
#        [-3.20031232e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.28603258e-01, -3.62167870e-01,  1.41192021e+00],
#        ...,
#        [-4.29480975e-05, -1.86298687e-01,  6.83121167e-01, ...,
#         -3.28603258e-01, -3.62167870e-01, -1.31560393e+00],
#        [-1.85606976e-01, -1.86298687e-01, -7.69578406e-01, ...,
#          2.85309024e-02, -9.85033311e-02, -1.31608822e+00],
#        [-7.00507951e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.28603258e-01, -3.62167870e-01, -1.31754109e+00]])

# %%
dbscan = DBSCAN(eps=1, min_samples=12)
dbscan.fit(X)
# Out:
# DBSCAN(eps=1, min_samples=12)

# %%
#Noisy samples are given the label -1.
dbscan.labels_
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
cl=pd.DataFrame(dbscan.labels_,columns=['cluster'])

# %%
cl
# Out:
#       cluster
# 0           0
# 1           0
# 2           0
# 3           0
# 4          -1
# ...       ...
# 3994        0
# 3995        0
# 3996        0
# 3997        0
# 3998        0
#
# [3999 rows x 1 columns]

# %%
pd.concat([air,cl],axis=1)
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 0               1                  0                0               7000
# 1               2                  0                0               6968
# 2               4                  0                0               7034
# 3               1                  0                0               6952
# 4              26               2077                4               6935
# ...           ...                ...              ...                ...
# 3994            4                200                1               1403
# 3995            5                  0                0               1395
# 3996            8                  0                0               1402
# 3997            1                500                1               1401
# 3998            0                  0                0               1398
#
#       cluster
# 0           0
# 1           0
# 2           0
# 3           0
# 4          -1
# ...       ...
# 3994        0
# 3995        0
# 3996        0
# 3997        0
# 3998        0
#
# [3999 rows x 11 columns]
